# %% [markdown]
# <a href="https://colab.research.google.com/github/ildacec/Python/blob/main/QuizPython_20230223.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Quiz 20230223

# %%
from google.colab import drive
drive.mount ('/content/drive')

from IPython.display import Image
#filename = "img1.png", width = 600, height = 300
Image (filename ='/content/drive/MyDrive/Colab Notebooks/Python/QuizPython_20230223.PNG', width = 500, height = 300)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dic = {1: 10, 2: 20, 3: 30}
print(list(dic)) 

#Solo imprime los keys
# Out:
# [1, 2, 3]
